# %%
import sys
import os

# Aggiunge la cartella radice del progetto al percorso di ricerca di Python
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import sentence_transformers
print(sentence_transformers.__version__)

model = SentenceTransformer()
print(model)           # se è vuoto, il caricamento è fallito
print(list(model.modules()))  # deve avere almeno Transformer + Pooling
# Out:
# 3.2.1
# SentenceTransformer(
#   (0): None
# )
# [SentenceTransformer(
#   (0): None
# )]

# %%
# Cella 1 - pulisci i file .pyc corrotti e reinstalla
import subprocess
subprocess.run(["find", "/opt/conda", "-name", "*.pyc", "-delete"])
subprocess.run(["pip", "install", "--force-reinstall", "--no-cache-dir", 
                "torch", "sentence-transformers"])

# %%
import app.core.config as config
#import app.core.json_prompt_read as json_prompt_read
from sentence_transformers import SentenceTransformer


class PromptEmbedder:
    def __init__(self, model):
        self.model = model

    def embed(self, prompt):
        # Use the model to generate an embedding for the prompt
        embedding = self.model.encode(prompt)
        return embedding

if __name__ == "__main__":

    # Load the model specified in the config
    model_name = config.EMBEDDING_MODEL
    model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')

    embedder = PromptEmbedder(model)
    #json_path = "prompt.json"

    #prompt = json_prompt_read.read_json_prompt(json_path)
    prompt = "What is the capital of France?"

    # Get the embedding for the prompt
    embedding = embedder.embed(prompt)
    print("Embedding for the prompt:", embedding)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 23932.93it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Embedding for the prompt: [ 8.20481256e-02  3.60555090e-02 -3.89288785e-03 -4.88104438e-03
#   2.56511495e-02 -5.71434796e-02  1.21915974e-02  4.67891945e-03
#   3.49498540e-02 -2.24219318e-02 -8.00525211e-03 -1.09353527e-01
#   2.27247663e-02 -2.93208770e-02 -4.35220860e-02 -1.20241210e-01
#  -8.48650874e-04 -1.81501284e-02  5.61295375e-02  3.08525586e-03
#   2.33635050e-03 -1.68392621e-02  6.36246949e-02 -2.36602128e-02
#   3.14935446e-02 -3.47979255e-02 -2.05488764e-02 -2.79097911e-03
#  -1.10379932e-02 -3.61267254e-02  5.41411191e-02 -3.66171524e-02
#  -2.50086728e-02 -3.81704345e-02 -4.96036299e-02 -1.51480902e-02
#   2.13150140e-02 -1.27404584e-02  7.67009333e-02  4.43557501e-02
#  -1.08348643e-02 -2.97600012e-02 -1.69704612e-02 -2.46918537e-02
#   8.08707345e-03  4.35876995e-02  7.17748702e-03  7.55013004e-02
#   3.28066312e-02 -6.20464161e-02  6.67789951e-02  2.70913746e-02
#  -4.56894636e-02 -3.14411372e-02 -3.11552510e-02  9.15368348e-02
#  -1.78819487e-03 -1.12826312e-02  3.64992917e-02  5.69271110e-02
#   2.29996792e-03 -3.77505608e-02 -1.54846599e-02  5.23914360e-02
#   6.03644289e-02 -1.66483279e-02  8.80994834e-03 -6.62230980e-03
#  -1.06297083e-01  1.71590620e-03 -4.83058430e-02 -2.97687147e-02
#   4.32554074e-03 -8.56741220e-02  6.62079155e-02 -5.51835820e-02
#  -1.13326602e-01  5.08402139e-02 -9.31724068e-03  6.00673910e-03
#   2.10127160e-02 -2.25154832e-02  4.72698943e-04  5.63897341e-02
